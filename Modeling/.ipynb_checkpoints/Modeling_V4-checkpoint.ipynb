# %% [markdown]
# # V4 Modeling

# %%
# ==========
# 0. 패키지
# ==========

import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import lightgbm as lgb
import matplotlib.pyplot as plt
from pathlib import Path

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import (
    roc_auc_score,
    average_precision_score,
    f1_score,
    precision_score,
    recall_score,
    confusion_matrix,
    classification_report
)
from sklearn.impute import SimpleImputer

# %%
pd.set_option('display.max_rows', 150)
pd.set_option('display.max_columns', 150)

# %%
# ===============
# 1. 데이터 로드
# ===============
DATA_DIR = Path('../Data')
train = pd.read_csv(DATA_DIR / "train_V4.csv")
test = pd.read_csv(DATA_DIR / "test_V4.csv")

print("train shape:", train.shape)
print("test shape :", test.shape)

TARGET = "fraud"

X = train.drop(columns=[TARGET]).copy()
y = train[TARGET].copy()
X_test = test.copy()

print("Fraud rate:", y.mean())
# Out:
# train shape: (18000, 153)
# test shape : (12000, 152)
# Fraud rate: 0.1582222222222222

# %%
# ===========
# 2. CV 설정
# ===========
N_SPLITS = 5
RANDOM_STATE = 2542

skf = StratifiedKFold(
    n_splits=N_SPLITS,
    shuffle=True,
    random_state=RANDOM_STATE
)

# %%
# ==========================================
# 3. LightGBM 파라미터
# ------------------------------------------
# 불균형 데이터이므로 scale_pos_weight 반영
# ==========================================
pos = (y == 1).sum()
neg = (y == 0).sum()
scale_pos_weight = (neg / pos) * 1.1

params = {
    "objective": "binary",
    "metric": "auc",
    "boosting_type": "gbdt",
    "learning_rate": 0.03,
    "num_leaves": 64,
    "max_depth": -1,
    "min_child_samples": 20,
    "subsample": 0.8,
    "subsample_freq": 1,
    "colsample_bytree": 0.8,
    "reg_alpha": 0.1,
    "reg_lambda": 0.5,
    "n_estimators": 10000,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "scale_pos_weight": scale_pos_weight,
    "verbosity": -1,
}

# %%
# ==================
# 4. Fold 반복 학습
# ==================
# 결과 저장 변수
oof_pred = np.zeros(len(X))
oof_pred_label = np.zeros(len(X), dtype=int)
test_pred = np.zeros(len(X_test))

fold_scores = []
feature_importance_list = []
models = []

for fold, (train_idx, valid_idx) in enumerate(skf.split(X, y), 1):
    print(f"\n{'='*20} Fold {fold} {'='*20}")

    X_train, X_valid = X.iloc[train_idx].copy(), X.iloc[valid_idx].copy()
    y_train, y_valid = y.iloc[train_idx].copy(), y.iloc[valid_idx].copy()

    # 클래스 불균형 반영
    neg = (y_train == 0).sum()
    pos = (y_train == 1).sum()
    scale_pos_weight = neg / pos

    model = lgb.LGBMClassifier(**params)

    fit_kwargs = dict(
        X=X_train,
        y=y_train,
        eval_set=[(X_valid, y_valid)],
        eval_metric="auc",
        callbacks=[
            lgb.early_stopping(stopping_rounds=300),
            lgb.log_evaluation(period=200)
        ]
    )

    model.fit(**fit_kwargs)

    # validation prediction
    threshold = 0.4
    valid_pred_proba = model.predict_proba(X_valid)[:, 1]
    valid_pred_label = (valid_pred_proba >= threshold).astype(int)

    # OOF 저장
    oof_pred[valid_idx] = valid_pred_proba
    oof_pred_label[valid_idx] = valid_pred_label

    # test prediction 저장
    test_pred += model.predict_proba(X_test)[:, 1] / N_SPLITS

    # fold metric
    fold_auc = roc_auc_score(y_valid, valid_pred_proba)
    fold_pr_auc = average_precision_score(y_valid, valid_pred_proba)
    fold_f1 = f1_score(y_valid, valid_pred_label, zero_division=0)

    print(f"Fold {fold} ROC-AUC : {fold_auc:.4f}")
    print(f"Fold {fold} PR-AUC  : {fold_pr_auc:.4f}")
    print(f"Fold {fold} F1      : {fold_f1:.4f}")

    fold_scores.append({
        "fold": fold,
        "roc_auc": fold_auc,
        "pr_auc": fold_pr_auc,
        "f1": fold_f1
    })

    # feature importance 저장
    fold_importance = pd.DataFrame({
        "feature": X.columns,
        "importance": model.feature_importances_,
        "fold": fold
    })
    feature_importance_list.append(fold_importance)

    models.append(model)
# Out:
# ==================== Fold 1 ====================
# Training until validation scores don't improve for 300 rounds
# [200]	valid_0's auc: 0.675078
# [400]	valid_0's auc: 0.66836
# Early stopping, best iteration is:
# [123]	valid_0's auc: 0.68057
# Fold 1 ROC-AUC : 0.6806
# Fold 1 PR-AUC  : 0.2737
# Fold 1 F1      : 0.3434
#
# ==================== Fold 2 ====================
# Training until validation scores don't improve for 300 rounds
# [200]	valid_0's auc: 0.702469
# Early stopping, best iteration is:
# [66]	valid_0's auc: 0.707353
# Fold 2 ROC-AUC : 0.7074
# Fold 2 PR-AUC  : 0.3043
# Fold 2 F1      : 0.3617
#
# ==================== Fold 3 ====================
# Training until validation scores don't improve for 300 rounds
# [200]	valid_0's auc: 0.676118
# [400]	valid_0's auc: 0.663783
# Early stopping, best iteration is:
# [112]	valid_0's auc: 0.681269
# Fold 3 ROC-AUC : 0.6813
# Fold 3 PR-AUC  : 0.2701
# Fold 3 F1      : 0.3436
#
# ==================== Fold 4 ====================
# Training until validation scores don't improve for 300 rounds
# [200]	valid_0's auc: 0.686516
# Early stopping, best iteration is:
# [66]	valid_0's auc: 0.694053
# Fold 4 ROC-AUC : 0.6941
# Fold 4 PR-AUC  : 0.2933
# Fold 4 F1      : 0.3494
#
# ==================== Fold 5 ====================
# Training until validation scores don't improve for 300 rounds
# [200]	valid_0's auc: 0.69504
# [400]	valid_0's auc: 0.687353
# Early stopping, best iteration is:
# [101]	valid_0's auc: 0.696382
# Fold 5 ROC-AUC : 0.6964
# Fold 5 PR-AUC  : 0.2801
# Fold 5 F1      : 0.3530

# %%
# ==================
# 5. Fold 결과 요약
# ==================
score_df = pd.DataFrame(fold_scores)

print("\n========== Fold Scores ==========")
print(score_df)

print("\n========== CV Mean Scores ==========")
print(f"Mean ROC-AUC : {score_df['roc_auc'].mean():.4f}")
print(f"Std  ROC-AUC : {score_df['roc_auc'].std():.4f}")
print(f"Mean PR-AUC  : {score_df['pr_auc'].mean():.4f}")
print(f"Mean F1      : {score_df['f1'].mean():.4f}")
# Out:
# ========== Fold Scores ==========
#    fold   roc_auc    pr_auc        f1
# 0     1  0.680570  0.273731  0.343358
# 1     2  0.707353  0.304256  0.361748
# 2     3  0.681269  0.270115  0.343616
# 3     4  0.694053  0.293256  0.349388
# 4     5  0.696382  0.280100  0.353038
#
# ========== CV Mean Scores ==========
# Mean ROC-AUC : 0.6919
# Std  ROC-AUC : 0.0112
# Mean PR-AUC  : 0.2843
# Mean F1      : 0.3502

# %%
# ==========================
# 6. 전체 OOF 기준 성능 평가
# ==========================
oof_auc = roc_auc_score(y, oof_pred)
oof_pr_auc = average_precision_score(y, oof_pred)
oof_f1 = f1_score(y, oof_pred_label, zero_division=0)

print("\n========== OOF Overall Performance ==========")
print(f"OOF ROC-AUC : {oof_auc:.4f}")
print(f"OOF PR-AUC  : {oof_pr_auc:.4f}")
print(f"OOF F1      : {oof_f1:.4f}")

print("\n========== OOF Confusion Matrix ==========")
print(confusion_matrix(y, oof_pred_label))

print("\n========== OOF Classification Report ==========")
print(classification_report(y, oof_pred_label, digits=4, zero_division=0))
# Out:
# ========== OOF Overall Performance ==========
# OOF ROC-AUC : 0.6908
# OOF PR-AUC  : 0.2767
# OOF F1      : 0.3502
#
# ========== OOF Confusion Matrix ==========
# [[8163 6989]
#  [ 760 2088]]
#
# ========== OOF Classification Report ==========
#               precision    recall  f1-score   support
#
#          0.0     0.9148    0.5387    0.6781     15152
#          1.0     0.2300    0.7331    0.3502      2848
#
#     accuracy                         0.5695     18000
#    macro avg     0.5724    0.6359    0.5142     18000
# weighted avg     0.8065    0.5695    0.6262     18000

# %%
# ===========================
# 7. 평균 Feature Importance
# ===========================
importance_df = pd.concat(feature_importance_list, axis=0)

mean_importance = (
    importance_df
    .groupby("feature")["importance"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

print("\n========== Mean Feature Importance ==========")
print(mean_importance.head(20))
# Out:
# ========== Mean Feature Importance ==========
#                          feature  importance
# 0                  age_of_driver       338.8
# 1             zip_fraud_rate_oof       303.4
# 2                 vehicle_weight       296.6
# 3                      liab_prct       293.6
# 4                   safty_rating       254.4
# 5                  annual_income       253.4
# 6      income_safety_interaction       242.0
# 7                      claim_day       236.0
# 8   vehicle_price_per_driver_age       233.4
# 9               price_per_weight       229.8
# 10      composite_x_income_ratio       201.8
# 11       vehicle_to_income_ratio       200.2
# 12      residual_to_income_ratio       189.6
# 13      estimated_residual_value       130.2
# 14                   claim_month       117.6
# 15                     month_cos       101.8
# 16            high_education_ind        99.2
# 17            past_num_of_claims        94.0
# 18                 vehicle_price        91.2
# 19                marital_status        86.4

# %%
# =============================
# 8. Feature Importance 시각화
# =============================
top_k = 20

plt.figure(figsize=(10, 7))
plt.barh(
    mean_importance["feature"].head(top_k)[::-1],
    mean_importance["importance"].head(top_k)[::-1]
)
plt.title("Top 20 Mean Feature Importance (CV)")
plt.xlabel("Mean Importance")
plt.tight_layout()
plt.show()

# %%
# ====================
# 9. Recall@TopK 함수
# ====================
def recall_at_k(y_true, pred_prob, k_ratio=0.1):
    k = int(len(pred_prob) * k_ratio)
    top_idx = np.argsort(pred_prob)[::-1][:k]
    recall = y_true.iloc[top_idx].sum() / y_true.sum()
    return recall

# %%
# =====================
# 10. Recall@TopK 출력
# =====================
k_list = [0.01, 0.03, 0.05, 0.10, 0.20, 0.30]

print("\n========== Recall@TopK ==========")
for k in k_list:
    recall_k = recall_at_k(y, oof_pred, k_ratio=k)
    print(f"Recall@Top{int(k*100)}%: {recall_k:.4f}")
# Out:
# ========== Recall@TopK ==========
# Recall@Top1%: 0.0256
# Recall@Top3%: 0.0702
# Recall@Top5%: 0.1141
# Recall@Top10%: 0.2177
# Recall@Top20%: 0.3739
# Recall@Top30%: 0.5109

# %%
# ============================
# 11. 평균 Feature Importance
# ============================
importance_df = pd.concat(feature_importance_list, axis=0)

mean_importance = (
    importance_df
    .groupby("feature")["importance"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

print("\n========== Mean Feature Importance ==========")
print(mean_importance.head(150))
# Out:
# ========== Mean Feature Importance ==========
#                                         feature  importance
# 0                                 age_of_driver       338.8
# 1                            zip_fraud_rate_oof       303.4
# 2                                vehicle_weight       296.6
# 3                                     liab_prct       293.6
# 4                                  safty_rating       254.4
# 5                                 annual_income       253.4
# 6                     income_safety_interaction       242.0
# 7                                     claim_day       236.0
# 8                  vehicle_price_per_driver_age       233.4
# 9                              price_per_weight       229.8
# 10                     composite_x_income_ratio       201.8
# 11                      vehicle_to_income_ratio       200.2
# 12                     residual_to_income_ratio       189.6
# 13                     estimated_residual_value       130.2
# 14                                  claim_month       117.6
# 15                                    month_cos       101.8
# 16                           high_education_ind        99.2
# 17                           past_num_of_claims        94.0
# 18                                vehicle_price        91.2
# 19                               marital_status        86.4
# 20                                   claim_year        84.8
# 21                             accident_parking        84.8
# 22                           address_change_ind        84.0
# 23                              day_of_week_sin        80.6
# 24                     payout_to_residual_ratio        80.0
# 25                        claim_to_weight_ratio        74.2
# 26                            payout_per_safety        72.2
# 27                       payout_to_income_ratio        71.0
# 28                                    month_sin        70.0
# 29                             claim_est_payout        69.2
# 30                            safety_risk_score        67.2
# 31                        payout_to_price_ratio        65.2
# 32                              day_of_week_num        63.4
# 33                               witness_absent        62.4
# 34                             accident_highway        61.6
# 35                               age_of_vehicle        56.6
# 36                              day_of_week_cos        55.6
# 37                            log_annual_income        51.4
# 38                         composite_risk_score        41.8
# 39                           log_vehicle_weight        41.8
# 40                          witness_present_ind        41.4
# 41                           living_status_rent        37.2
# 42                         income_claim_bin_gap        35.0
# 43                      policy_report_filed_ind        33.6
# 44                claim_to_weight_ratio_clipped        32.6
# 45                           unstable_lifestyle        31.6
# 46             payout_to_residual_ratio_clipped        25.4
# 47                            log_vehicle_price        24.4
# 48                payout_to_price_ratio_clipped        24.2
# 49                              log_past_claims        21.8
# 50               payout_to_income_ratio_clipped        21.8
# 51                             log_claim_payout        16.2
# 52                         residual_value_ratio        14.6
# 53                               channel_broker        14.0
# 54                               veh_size_Large        13.6
# 55                             no_police_report        12.6
# 56                       extreme_liability_flag        12.4
# 57                             broker_no_report        11.8
# 58                              no_verification        11.6
# 59                              veh_size_Medium        10.2
# 60                               channel_online         9.8
# 61                               accident_local         8.6
# 62                             is_weekend_claim         8.6
# 63                             serial_no_report         7.2
# 64                              is_winter_claim         6.2
# 65                            serial_no_witness         6.0
# 66                              is_summer_claim         5.6
# 67                              is_monday_claim         5.4
# 68                                claim_quarter         5.4
# 69                         no_witness_no_report         4.6
# 70                           weekend_no_witness         4.4
# 71                       old_vehicle_high_claim         4.4
# 72                            repeat_no_witness         4.2
# 73                             is_senior_driver         4.0
# 74                       new_vehicle_high_claim         3.8
# 75                         is_high_risk_zip_oof         2.8
# 76                        low_income_high_claim         2.6
# 77                                   income_bin         2.6
# 78                                   risk_grade         2.4
# 79                  repeat_claim_full_liability         1.8
# 80                           is_month_end_claim         1.8
# 81                low_income_overpriced_vehicle         1.6
# 82               high_residual_ratio_and_repeat         1.4
# 83                               is_high_income         1.4
# 84                            is_serial_claimer         1.4
# 85                          full_liability_flag         1.4
# 86          no_witness_no_report_full_liability         1.2
# 87                              low_safety_flag         1.2
# 88                            is_year_end_claim         1.0
# 89                          zero_liability_flag         1.0
# 90                              witness_unknown         0.8
# 91                            is_repeat_claimer         0.8
# 92                             new_vehicle_flag         0.6
# 93                              is_young_driver         0.6
# 94                                is_low_income         0.4
# 95                       high_payout_ratio_flag         0.4
# 96                               age_is_outlier         0.4
# 97                           is_extreme_claimer         0.4
# 98      payout_to_price_ratio_clipped_top5_flag         0.2
# 99              high_income_ratio_and_no_report         0.2
# 100                     overpriced_vehicle_flag         0.2
# 101                       unsafe_full_liability         0.2
# 102                      expensive_vehicle_flag         0.2
# 103                           zero_payout_claim         0.2
# 104                     young_expensive_vehicle         0.2
# 105                                   claim_bin         0.0
# 106                                veh_size_nan         0.0
# 107    payout_to_income_ratio_clipped_top1_flag         0.0
# 108                            high_payout_flag         0.0
# 109                            old_vehicle_flag         0.0
# 110  payout_to_residual_ratio_clipped_top5_flag         0.0
# 111  payout_to_residual_ratio_clipped_top1_flag         0.0
# 112                       over_value_claim_flag         0.0
# 113     payout_to_price_ratio_clipped_top1_flag         0.0
# 114    payout_to_income_ratio_clipped_top5_flag         0.0
# 115                         extreme_payout_flag         0.0

# %%
# =====================
# 12. Threshold Tuning
# =====================
threshold_list = np.arange(0.05, 0.51, 0.05)

result_list = []

print("========== Threshold Tuning ==========")

for th in threshold_list:
    pred_label = (oof_pred >= th).astype(int)

    f1 = f1_score(y, pred_label, zero_division=0)
    precision = precision_score(y, pred_label, zero_division=0)
    recall = recall_score(y, pred_label, zero_division=0)

    tn, fp, fn, tp = confusion_matrix(y, pred_label).ravel()

    result_list.append({
        "threshold": th,
        "f1": f1,
        "precision": precision,
        "recall": recall,
        "tp": tp,
        "fp": fp,
        "fn": fn,
        "tn": tn
    })

    print(f"\nThreshold = {th:.2f}")
    print(f"F1        : {f1:.4f}")
    print(f"Precision : {precision:.4f}")
    print(f"Recall    : {recall:.4f}")
    print(f"TP={tp} FP={fp} FN={fn} TN={tn}")

result_df = pd.DataFrame(result_list)
# Out:
# ========== Threshold Tuning ==========
#
# Threshold = 0.05
# F1        : 0.2748
# Precision : 0.1593
# Recall    : 1.0000
# TP=2848 FP=15031 FN=0 TN=121
#
# Threshold = 0.10
# F1        : 0.2852
# Precision : 0.1664
# Recall    : 0.9965
# TP=2838 FP=14218 FN=10 TN=934
#
# Threshold = 0.15
# F1        : 0.2951
# Precision : 0.1736
# Recall    : 0.9835
# TP=2801 FP=13337 FN=47 TN=1815
#
# Threshold = 0.20
# F1        : 0.3057
# Precision : 0.1818
# Recall    : 0.9607
# TP=2736 FP=12315 FN=112 TN=2837
#
# Threshold = 0.25
# F1        : 0.3175
# Precision : 0.1915
# Recall    : 0.9284
# TP=2644 FP=11164 FN=204 TN=3988
#
# Threshold = 0.30
# F1        : 0.3270
# Precision : 0.2010
# Recall    : 0.8754
# TP=2493 FP=9908 FN=355 TN=5244
#
# Threshold = 0.35
# F1        : 0.3399
# Precision : 0.2148
# Recall    : 0.8139
# TP=2318 FP=8474 FN=530 TN=6678
#
# Threshold = 0.40
# F1        : 0.3502
# Precision : 0.2300
# Recall    : 0.7331
# TP=2088 FP=6989 FN=760 TN=8163
#
# Threshold = 0.45
# F1        : 0.3589
# Precision : 0.2493
# Recall    : 0.6404
# TP=1824 FP=5492 FN=1024 TN=9660
#
# Threshold = 0.50
# F1        : 0.3537
# Precision : 0.2684
# Recall    : 0.5186
# TP=1477 FP=4027 FN=1371 TN=11125

# %%
# ===================
# 13. Best Threshold
# ===================
best_row = result_df.loc[result_df["f1"].idxmax()]

print("\n========== Best Threshold ==========")
print(best_row)
# Out:
# ========== Best Threshold ==========
# threshold       0.450000
# f1              0.358914
# precision       0.249317
# recall          0.640449
# tp           1824.000000
# fp           5492.000000
# fn           1024.000000
# tn           9660.000000
# Name: 8, dtype: float64

# %% [markdown]
# - 미미한 성능 향상 발견
# - feature cleaning 필요
